# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,"bo")

# %%
plt.plot(x,y,"rx")

# %%
plt.plot(x,y,"bD:")

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8c189b58b0>,
# ...
#  [Text(1.1, 0.0, ''),
#   Text(1.0982060144323316, 0.06279768996272098, ''),
#   Text(1.0714131104390903, 0.24914643641688675, ''),
#   Text(0.9578206904715764, 0.5409062071233356, ''),
#   Text(0.6717126826129879, 0.8710924589369738, ''),
#   Text(0.15654633947694596, 1.0888035835706864, ''),
#   Text(-0.5133340491307307, 0.9728762274837682, ''),
#   Text(-1.0360287953626528, 0.36965434554379384, ''),
#   Text(-0.9578207031323996, -0.5409061847039242, ''),
#   Text(-0.09413258651866149, -1.0959648973189364, ''),
#   Text(0.9253788411904255, -0.5947049691040638, '')])

# %%
plt.scatter(x,y)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8c18b32fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8c18b42730>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8c18b32ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8c18b42e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8c18b4c220>],
#  'means': []}
